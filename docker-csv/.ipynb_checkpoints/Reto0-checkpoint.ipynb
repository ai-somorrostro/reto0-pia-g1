# %%
import pandas as pd

# %%
rawdata=pd.read_csv('precio.csv')
rawdata2=pd.read_csv('criptomoneda.csv')

# %%
df_precios=rawdata
df_criptos=rawdata2

# %%
df_precios
# Out:
#      rank      price_usd  percent_change_24h  percent_change_7d  price_btc  \
# 0       1  123856.990000               -0.91              12.46   1.000000
# 1       2    4561.130000               -0.12              12.96   0.036832
# 2       3       2.990000               -1.55               6.02   0.000024
# 3       4       1.000000                0.01              -0.11   0.000008
# 4       5    1214.800000                3.52              24.12   0.009810
# ..    ...            ...                 ...                ...        ...
# 795    96      21.450000               -2.86               7.45   0.000173
# 796    97       2.910000               -3.69               9.76   0.000024
# 797    98       0.189027               -2.51              16.11   0.000002
# 798    99       0.764329               -4.97               3.97   0.000006
# 799   100       0.146211               -1.75               1.83   0.000001
#
#                            date      id
# 0    2025-10-06T06:36:19.455475      90
# 1    2025-10-06T06:36:19.455475      80
# 2    2025-10-06T06:36:19.455475      58
# 3    2025-10-06T06:36:19.455475     518
# 4    2025-10-06T06:36:19.455475    2710
# ..                          ...     ...
# 795  2025-10-06T08:28:35.677450   56821
# 796  2025-10-06T08:28:35.677450   47371
# 797  2025-10-06T08:28:35.677450     447
# 798  2025-10-06T08:28:35.677450  121613
# 799  2025-10-06T08:28:35.677450  121599
#
# [800 rows x 7 columns]

# %%
df_total = pd.merge(df_criptos, df_precios, left_on='id', right_on='id', how='inner')

# %%
df_total
# Out:
#          id       name symbol  rank      price_usd  percent_change_24h  \
# 0        90    Bitcoin    BTC     1  123856.990000               -0.91
# 1        90    Bitcoin    BTC     1  123990.620000               -0.75
# 2        90    Bitcoin    BTC     1  123896.360000               -0.88
# 3        90    Bitcoin    BTC     1  123896.360000               -0.88
# 4        90    Bitcoin    BTC     1  123871.130000               -0.93
# ..      ...        ...    ...   ...            ...                 ...
# 787  121613  dogwifhat    WIF    99       0.768158               -1.82
# 788  121613  dogwifhat    WIF    98       0.770779               -2.27
# 789  121613  dogwifhat    WIF    97       0.771291               -2.52
# 790  121613  dogwifhat    WIF    97       0.767982               -2.66
# 791  121613  dogwifhat    WIF    99       0.764329               -4.97
#
#      percent_change_7d  price_btc                        date
# 0                12.46   1.000000  2025-10-06T06:36:19.455475
# 1                12.54   1.000000  2025-10-06T06:41:07.322076
# 2                12.35   1.000000  2025-10-06T07:02:55.248619
# 3                12.35   1.000000  2025-10-06T07:04:14.966707
# 4                12.36   1.000000  2025-10-06T07:13:26.298423
# ..                 ...        ...                         ...
# 787               4.67   0.000006  2025-10-06T07:04:14.966707
# 788               5.22   0.000006  2025-10-06T07:13:26.298423
# 789               5.57   0.000006  2025-10-06T07:18:51.038274
# 790               4.87   0.000006  2025-10-06T07:39:54.729602
# 791               3.97   0.000006  2025-10-06T08:28:35.677450
#
# [792 rows x 9 columns]

# %%
df_bitcoin = df_total[df_total['name'] == "Bitcoin"]
df_bitcoin
# Out:
#    id     name symbol  rank  price_usd  percent_change_24h  percent_change_7d  \
# 0  90  Bitcoin    BTC     1  123856.99               -0.91              12.46
# 1  90  Bitcoin    BTC     1  123990.62               -0.75              12.54
# 2  90  Bitcoin    BTC     1  123896.36               -0.88              12.35
# 3  90  Bitcoin    BTC     1  123896.36               -0.88              12.35
# 4  90  Bitcoin    BTC     1  123871.13               -0.93              12.36
# 5  90  Bitcoin    BTC     1  123937.85               -0.86              12.53
# 6  90  Bitcoin    BTC     1  123829.22               -0.69              12.25
# 7  90  Bitcoin    BTC     1  123608.58               -0.86              11.81
#
#    price_btc                        date
# 0        1.0  2025-10-06T06:36:19.455475
# 1        1.0  2025-10-06T06:41:07.322076
# 2        1.0  2025-10-06T07:02:55.248619
# 3        1.0  2025-10-06T07:04:14.966707
# 4        1.0  2025-10-06T07:13:26.298423
# 5        1.0  2025-10-06T07:18:51.038274
# 6        1.0  2025-10-06T07:39:54.729602
# 7        1.0  2025-10-06T08:28:35.677450

# %%
from influxdb_client import InfluxDBClient

# %%
my_token="LbKYCkDRS7jmz-k_PBa_Zq5doOV2XFkgr3pWLBMdHeVwxw7agEZtXjc1dGkTsc3gVl9r6ihU9exA3sw0kJexfg=="

# %%
client = InfluxDBClient(url="http://localhost:8086", token=my_token, org="somorrostro")

# %%
write_client = client.write_api()

# %%
write_client.write("reto0-pruebas-bucket", record=rawdata, data_frame_measurement_name="Bitcoin")
